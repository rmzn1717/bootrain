# %% [markdown]
# # <font color=blue>Assignments for "Visualization with Matplotlib"</font>

# %% [markdown]
# In this assignment, you will make some plots about Corona. First, download the [Coronavirus Source Data](https://ourworldindata.org/coronavirus-source-data).
#
# - First, filter the data for four countries (Spain, France, Germany, Italy) and the last 100 days.
#
# - Create a figure with two subplots. The left subplot will show total cases, and the right one will show total deaths for these countries
#
# - Set titles, X and Y labels, change the font, font size, and font color for each subplot.
#
# - Change color, width, and type of lines.
#
# - Put a legend to bottom right.
#
# - Change the color and rotation of the X-axis ticks.
#
# - And set a title for the figure (not for the plots).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('owid-covid-data.csv', parse_dates = ["date"], low_memory = False)   #bu da guzel bir read

df.tail()
# Out:
#       iso_code continent       location       date  total_cases  new_cases  \
# 33412      NaN       NaN  International 2020-02-28        705.0        0.0
# 33413      NaN       NaN  International 2020-02-29        705.0        0.0
# 33414      NaN       NaN  International 2020-03-01        705.0        0.0
# 33415      NaN       NaN  International 2020-03-02        705.0        0.0
# 33416      NaN       NaN  International 2020-03-10        696.0       -9.0
#
#        total_deaths  new_deaths  total_cases_per_million  \
# 33412           4.0         0.0                      NaN
# 33413           6.0         2.0                      NaN
# 33414           6.0         0.0                      NaN
# 33415           6.0         0.0                      NaN
# 33416           7.0         1.0                      NaN
#
#        new_cases_per_million  ...  aged_70_older  gdp_per_capita  \
# 33412                    NaN  ...            NaN             NaN
# ...

# %%
data=df[df['location'].isin(['Spain', 'France', 'Germany', 'Italy'])]
s_data = data.sort_values(by='date').tail(400)              
s_data
# Out:
#       iso_code continent location       date  total_cases  new_cases  \
# 10865      FRA    Europe   France 2020-04-20     112606.0      785.0
# 11692      DEU    Europe  Germany 2020-04-21     143457.0     1785.0
# 28146      ESP    Europe    Spain 2020-04-21     198421.0     2951.0
# 10866      FRA    Europe   France 2020-04-21     114657.0     2051.0
# 15496      ITA    Europe    Italy 2020-04-21     181228.0     2256.0
# ...        ...       ...      ...        ...          ...        ...
# 11790      DEU    Europe  Germany 2020-07-28     206242.0      633.0
# 10964      FRA    Europe   France 2020-07-28     183079.0     2551.0
# 10965      FRA    Europe   France 2020-07-29     183804.0      725.0
# 15595      ITA    Europe    Italy 2020-07-29     246488.0      202.0
# 11791      DEU    Europe  Germany 2020-07-29     206926.0      684.0
#
#        total_deaths  new_deaths  total_cases_per_million  \
# 10865       19718.0       395.0                 1725.141
# ...

# %%
fig = plt.figure(figsize=(15,5))

title_style = {'family': 'Arial', 'color': 'darkred', 'size': 20 }
axis_style  = {'family': 'Arial', 'color': 'darkblue', 'size': 15 }


plt.subplot(1,2,1)


plt.plot(data_s[s_data.location == 'France'].date,data_s[s_data.location == 'France']['total_cases'],\
         ls = ':', lw = 2, c = '#665fd1')
plt.plot(s_data[s_data.location == 'Spain'].date,s_data[s_data.location == 'Spain']['total_cases'],\
         ls = '--', lw = 2, c = '#cb416b')
plt.plot(s_data[s_data.location == 'Italy'].date,s_data[s_data.location == 'Italy']['total_cases'],\
         ls = '-', lw = 2, c= '#028f1e')
plt.plot(s_data[s_data.location == 'Germany'].date,s_data[s_data.location == 'Germany']['total_cases'],\
         ls = '-.', lw = 2, c = '#c65102')

plt.title('Total Cases',fontdict = title_style)

plt.legend(['France', 'Spain', 'Italy', 'Germany'], loc = 4)

plt.xlabel('Years',fontdict = axis_style)
plt.ylabel('Number of Total Cases',fontdict = axis_style)

plt.xticks(rotation = 45, fontsize = 12)


plt.subplot(1,2,2)

plt.plot(s_data[s_data.location == 'France'].date,s_data[s_data.location == 'France']['total_deaths'],\
         ls=':',lw=2, c = '#665fd1')
plt.plot(s_data[s_data.location == 'Spain'].date,s_data[s_data.location == 'Spain']['total_deaths'],\
         ls='--',lw=2, c = '#cb416b')
plt.plot(s_data[s_data.location == 'Italy'].date,s_data[s_data.location == 'Italy']['total_deaths'],\
         ls='-',lw=2, c = '#028f1e')
plt.plot(s_data[s_data.location == 'Germany'].date,s_data[s_data.location == 'Germany']['total_deaths'],\
         ls='-.',lw=2, c = '#c65102')

plt.title('Total Deaths', fontdict = title_style)

plt.legend(['France', 'Spain', 'Italy', 'Germany'], loc = 4)

plt.xlabel('Years',fontdict = axis_style)
plt.ylabel('Number of Total Deaths',fontdict = axis_style)

plt.xticks(rotation = 45, fontsize = 12)

fig.suptitle("Corona for 4 Countries",fontsize='20')

plt.show()
